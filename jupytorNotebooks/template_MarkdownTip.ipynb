# %% [markdown]
# # Markdown
# ### Markdown
#
# <h1>Markdown</h1>
# <h2>Markdown</h2>
# <h3>Markdown</h3>
#
# 파이썬 *파이썬* **파이썬** <U>파이썬</U>
#
# [비트코인 사이트](https://kr.investing.com/crypto/)
#
# - 첫째 항목
# - 둘째 항목
# - 셋째 항목
#
#
# 1. 첫째 항목
# 2. 둘째 항목
# 3. 셋째 항목
#
#
# $$f(x)=\frac{1}{\sigma\sqrt{2\pi}}$$
#
# |column|type|
# |:---:|:--:|
# |email|TEXT|
# |count|INTEGER|
#
# >여기서부터는
# >인용문 입니다.
# >마크다운을 잘 쓰면 노트북이 매우 풍부해 집니다.
#
# ```python
# status = Label(root)
# status.pack()
#
# def update():
#     req = Request(URL, headers=hdr)
#     page = urlopen(req)
#     html = BeautifulSoup(page, "html.parser")
#     txt = html.find(class_="newInput inputTextBox alertValue")
#     match = re.search("[0-9,.]+", str(txt))
#     # 현재가격
#     price = match.group()
#     bit_label.config(text=price)
#     # 현재시간
#     now = datetime.now()
#     current = now.strftime("%I:%M:%S %p %A")
#     status.config(text=f"최근 갱신 : {current}")
#
#     root.after(5000, update)
#
# update()
#
#
# ```
#
# ```javascrip
# for (int i=0; i<99; i++){
#     sum += i
# }
# ```
# <img src="images/dog.0.jpg" width="300"/>
#
# ## 수평 구분선
#
# ---
#
# ***
#
# ### 빈 cell 만들기
#
# ```
# <!--Empty Space for separating topics-->
# ```
