# %% [markdown]
# # 22. 자주 사용하는 Python Library 소개

# %% [markdown]
# ## os
#
# - 환경 변수나 디렉터리, 파일 등의 OS 자원을 제어할 수 있게 해주는 모듈이다

# %%
import os

os.environ['PATH']
# Out:
# 'C:\\Users\\trimu\\Miniconda3\\envs\\tf;C:\\Users\\trimu\\Miniconda3\\envs\\tf\\Library\\mingw-w64\\bin;C:\\Users\\trimu\\Miniconda3\\envs\\tf\\Library\\usr\\bin;C:\\Users\\trimu\\Miniconda3\\envs\\tf\\Library\\bin;C:\\Users\\trimu\\Miniconda3\\envs\\tf\\Scripts;C:\\Users\\trimu\\Miniconda3\\envs\\tf\\bin;C:\\Users\\trimu\\Miniconda3\\condabin;C:\\Program Files (x86)\\Common Files\\Oracle\\Java\\javapath;C:\\ProgramData\\Boxstarter;C:\\Users\\trimu\\Anaconda3\\Lib\\site-packages\\PyQt5;C:\\Python36\\Scripts;C:\\Python36;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0;C:\\Program Files\\Git\\cmd;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0;C:\\Program Files\\MySQL\\MySQL Utilities 1.6;C:\\WINDOWS\\System32\\OpenSSH;C:\\Program Files\\dotnet;C:\\ProgramData\\chocolatey\\bin;C:\\Program Files (x86)\\Yarn\\bin;C:\\Program Files\\Pandoc;C:\\Program Files (x86)\\Graphviz2.38\\bin;C:\\Users\\trimu\\AppData\\Local\\atom\\bin;C:\\Program Files\\Intel\\WiFi\\bin;C:\\Program Files\\Common Files\\Intel\\WirelessCommon;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0;C:\\WINDOWS\\System32\\OpenSSH;C:\\Program Files\\Java\\jdk-14.0.2\\bin;C:\\Program Files\\nodejs;C:\\Program Files\\Go\\bin;c:\\Program Files (x86)\\Intel\\Intel(R) Management Engine Components\\DAL;c:\\Program Files\\Intel\\Intel(R) Management Engine Components\\DAL;C:\\Users\\trimu\\AppData\\Roaming\\Python\\Python39\\Scripts;C:\\Users\\trimu\\AppData\\Roaming\\Python\\xgboost;C:\\Program Files\\MySQL\\MySQL Shell 8.0\\bin;C:\\Program Files\\mingw-w64\\x86_64-8.1.0-posix-seh-rt_v6-rev0\\mingw64\\bin;C:\\Users\\trimu\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C:\\Windows\\System32;C:\\Users\\trimu\\AppData\\Local\\Google\\Cloud SDK\\google-cloud-sdk\\bin;C:\\Users\\trimu\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\trimu\\AppData\\Roaming\\npm;C:\\Users\\trimu\\go\\bin;C:\\Users\\trimu\\AppData\\Roaming\\Python\\xgboost;.'

# %%
os.getcwd()
# Out:
# '/Users/ohyoungjea/OneDrive/AlgorithmPython-for-AI/jupytorNotebooks'

# %%
os.chdir("/Users/ohyoungjea/OneDrive/AlgorithmPython-for-AI/")

# %%
os.getcwd()
# Out:
# '/Users/ohyoungjea/OneDrive/AlgorithmPython-for-AI'

# %%
os.listdir()
# Out:
# ['Practice-Answer',
#  '.DS_Store',
#  'boilerplate.py',
#  'babynames',
#  '__pycache__',
#  '.spyproject',
#  'README.md',
#  '.ipynb_checkpoints',
#  '.git',
#  '.vscode',
#  '사전 설문.docx',
#  'jupytorNotebooks',
#  'AlgorithmPythonText.pdf',
#  'babynames.py']

# %%
os.chdir("/Users/ohyoungjea/OneDrive/AlgorithmPython-for-AI/jupytorNotebooks")

# %%
os.getcwd()
# Out:
# '/Users/ohyoungjea/OneDrive/AlgorithmPython-for-AI/jupytorNotebooks'

# %% [markdown]
# ## sys.path
#
# - 파이썬 모듈들이 저장되어 있는 위치를 나타낸다. 즉 이 위치에 있는 파이썬 모듈은 경로에 상관없이 어디에서나 불러올 수 있다.

# %%
import sys

sys.path
# Out:
# ['/Users/ohyoungjea/OneDrive/AlgorithmPython-for-AI/jupytorNotebooks',
#  '/Users/ohyoungjea/anaconda3/envs/tf20/lib/python37.zip',
#  '/Users/ohyoungjea/anaconda3/envs/tf20/lib/python3.7',
#  '/Users/ohyoungjea/anaconda3/envs/tf20/lib/python3.7/lib-dynload',
#  '',
#  '/Users/ohyoungjea/.local/lib/python3.7/site-packages',
#  '/Users/ohyoungjea/anaconda3/envs/tf20/lib/python3.7/site-packages',
#  '/Users/ohyoungjea/anaconda3/envs/tf20/lib/python3.7/site-packages/IPython/extensions',
#  '/Users/ohyoungjea/.ipython',
#  'C:\\Users\\trimu\\']

# %%
sys.path.append("C:\\Users\\trimu\\")

# %%
sys.path
# Out:
# ['/Users/ohyoungjea/OneDrive/AlgorithmPython-for-AI/jupytorNotebooks',
#  '/Users/ohyoungjea/anaconda3/envs/tf20/lib/python37.zip',
#  '/Users/ohyoungjea/anaconda3/envs/tf20/lib/python3.7',
#  '/Users/ohyoungjea/anaconda3/envs/tf20/lib/python3.7/lib-dynload',
#  '',
#  '/Users/ohyoungjea/.local/lib/python3.7/site-packages',
#  '/Users/ohyoungjea/anaconda3/envs/tf20/lib/python3.7/site-packages',
#  '/Users/ohyoungjea/anaconda3/envs/tf20/lib/python3.7/site-packages/IPython/extensions',
#  '/Users/ohyoungjea/.ipython',
#  'C:\\Users\\trimu\\',
#  'C:\\Users\\trimu\\']

# %% [markdown]
# ## pathlib.Path

# %%
from pathlib import Path

# %% [markdown]
# - subdirectory 를 나열
# - ```Path(directory_name)```

# %%
p = Path('.')
p
# Out:
# PosixPath('.')

# %%
[x for x in p.iterdir() if x.is_dir()]
# Out:
# [PosixPath('unzipped_content'),
#  PosixPath('images'),
#  PosixPath('30_sampleWebServer'),
#  PosixPath('__pycache__'),
#  PosixPath('unzipped_content_3'),
#  PosixPath('unzipped_content_2'),
#  PosixPath('.ipynb_checkpoints')]

# %% [markdown]
# - current directory 에서 pattern 검색

# %%
list(p.glob('*.py'))
# Out:
# [PosixPath('31_argument_parse.py'),
#  PosixPath('notebook_merge.py'),
#  PosixPath('module_test.py'),
#  PosixPath('writfile.py')]

# %% [markdown]
# ## os.walk
#
# - 모든 파일/폴더 출력하기

# %%
import os

workDIr = os.path.abspath('./unzipped_content')

for dirpath, dirnames, filenames in os.walk(workDIr):
    print(dirpath)
    print(dirnames)
    print(filenames)
# Out:
# /Users/ohyoungjea/OneDrive/AlgorithmPython-for-AI/jupytorNotebooks/unzipped_content
# []
# ['new_file.txt', 'new_file2.txt', 'new_file_2.txt', 'new_file_1.txt']

# %% [markdown]
# ## pickle

# %%
import pickle

f = open("test.pkl", 'wb')
data = {1: 'python', 2: 'you need'}

pickle.dump(data, f)
f.close()

# %%
f = open("test.pkl", 'rb')

data = pickle.load(f)
print(data)
# Out:
# {1: 'python', 2: 'you need'}

# %% [markdown]
# ## glob
#
# - 파일들의 리스트를 뽑을 때 사용

# %%
from glob import glob
glob('*.csv')
# Out:
# ['winequality-red.csv',
#  'winequality-2.csv',
#  'tmp.csv',
#  'Topic_Survey_Assignment.csv',
#  'cars.csv']

# %%
glob('images/*.png')
# Out:
# ['images/dict1.png', 'images/cropped-png.png']

# %% [markdown]
# ## time
#
# - ``time.time()``
#     - ``UTC``(Universal Time Coordinated 협정 세계 표준시)를 사용하여 현재 시간을 실수 형태로 돌려주는 함수
#     - 1970년 1월 1일 0시 0분 0초를 기준으로 지난 시간을 초 단위로 돌려준다
#
#
# - ``time.localtime``
#     - ``time.time()``이 돌려준 실수 값을 사용해서 연도, 월, 일, 시, 분, 초, ... 의 형태로 바꾸어 주는 함수
#
#
#
# - ``time.strftime``('출력할 형식 포맷 코드', ``time.localtime(time.time())``) - string from time
#
# ```
# %x  날짜를 출력, 현재 시간대 기준
# %c  날짜, 요일, 시간을 출력, 현재 시간대 기준
# %Y  네 자릿수 연도
# %m  숫자 월
# %d  일
# %H  시간(24시간)
# %M  분
# %S  초
# %z  시간대
# %a  요일 줄임말
# %A  요일
# %b  월 줄임말
# %B  월
# %I  시간(12시간)
# %p  AM, PM
# ```

# %%
import time

time.time()
# Out:
# 1611629009.650095

# %%
time.localtime(time.time())
# Out:
# time.struct_time(tm_year=2021, tm_mon=1, tm_mday=26, tm_hour=11, tm_min=43, tm_sec=30, tm_wday=1, tm_yday=26, tm_isdst=0)

# %%
time.strftime('%x', time.localtime(time.time()))
# Out:
# '01/26/21'

# %%
time.strftime('%c', time.localtime(time.time()))
# Out:
# 'Tue Jan 26 11:43:31 2021'

# %% [markdown]
# ## random
#
# - random은 난수(규칙이 없는 임의의 수)를 발생시키는 모듈이다

# %%
import random

random.random()
# Out:
# 0.481363996008223

# %%
random.randint(1, 10)
# Out:
# 3

# %% [markdown]
# ## Pillow
#
# - ``PIL(Python Image Library)`` 은 ``Pillow`` 의 old name
#
#
#     - 설치는 pip install pillow
#     - 사용은 import PIL

# %% [markdown]
# ### image 를 읽어서 display
#
# - ``Image.open()`` : image file open
#
#
# - internet 상의 image 는 byte code 로 전송되므로 ``BytesIO`` 를 이용하여 binary 로 변환

# %%
import requests
from PIL import Image
from io import BytesIO

def load_image(img_path):
    
    if "http" in img_path:
        response = requests.get(img_path)
        image = Image.open(BytesIO(response.content))
    else:
        image = Image.open(img_path)
    
    return image

# %%
url = "https://c.files.bbci.co.uk/12A9B/production/_111434467_gettyimages-1143489763.jpg"

# %%
import base64
response = requests.get(url)
Image.open(BytesIO(response.content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=976x549 at 0x7FA3B68D7110>

# %%
load_image(url)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=976x549 at 0x7FA3B8E84B90>

# %%
img = load_image("images/dog.0.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=499x375 at 0x7F9C5CC9D4D0>

# %%
print("Format: {0}\nSize: {1}\nMode: {2}".format(img.format, img.size, img.mode))
# Out:
# Format: JPEG
# Size: (499, 375)
# Mode: RGB

# %% [markdown]
# ### PIL 에 사전 정의된 Image Filter 를 이용하여 image 변환
#
# - ImageFilter.BLUR
# - CONTOUR
# - DETAIL
# - EDGE_ENHANCE
# - EDGE_ENHANCE_MORE
# - EMBOSS
# - FIND_EDGES
# - SHARPEN
# - SMOOTH
# - SMOOTH_MORE

# %%
from PIL import ImageFilter

img.filter(ImageFilter.BLUR)
# Out:
# <PIL.Image.Image image mode=RGB size=499x375 at 0x7F9C5DB0FE50>

# %%
img.filter(ImageFilter.CONTOUR)
# Out:
# <PIL.Image.Image image mode=RGB size=499x375 at 0x7F9C5CC95D10>

# %%
img.filter(ImageFilter.EMBOSS)
# Out:
# <PIL.Image.Image image mode=RGB size=499x375 at 0x7F9C5DB0FB10>

# %%
grayscale = img.convert('L')    # L : black and white mode
grayscale
# Out:
# <PIL.Image.Image image mode=L size=499x375 at 0x7F9C5CC9D590>

# %% [markdown]
# ### image 회전

# %%
img.rotate(180)
# Out:
# <PIL.Image.Image image mode=RGB size=499x375 at 0x7F9C5DB18810>

# %% [markdown]
# ### PIL 을 이용한 image 자르기
#
# ```img.crop((left, upper, right, lower))```  - left/upper corner, right/lower corner

# %%
cropped = img.crop((100, 50, 400, 300))    # cropping (left, upper, right, lower) pixel coordinates
cropped
# Out:
# <PIL.Image.Image image mode=RGB size=300x250 at 0x7F9C5DB1EF10>

# %% [markdown]
# ### image save

# %%
cropped.save('images/cropped-png.png')

# %%
img = Image.open('images/cropped-png.png')
print(img.format)
# Out:
# PNG

# %% [markdown]
# # Python 을 이용하여 zipfile handling 하는 방법
#
# ### zipfile
# - zip archive object 를 생성하고 개별 file 을 add
#
# ### shutl
# - 전체 directory 를 빠르게 compress

# %%
# sample file 2 개 생성
f = open('new_file_1.txt', 'w')
f.write('이것은 첫번째 테스트 file 입니다.')
f.close()

f = open('new_file_2.txt', 'w')
f.write('두번째 테스트 file 입니다')
f.close()

# %%
import zipfile

# empty zipfile object 생성
comp_file = zipfile.ZipFile('new_compressed_file.zip', 'w')

# %%
# empty object 에 압축할 file 추가
comp_file.write('new_file_1.txt')
comp_file.write('new_file_2.txt')

# %%
comp_file.close()

# %% [markdown]
# ## Extract from zipfile

# %%
# 읽어들일 zipfile object 생성
zip_object = zipfile.ZipFile('new_compressed_file.zip', 'r')

# 새로운 directory 에 모든 file 압축 해제
zip_object.extractall('unzipped_content')

# %%
# 개별 file 해제 (file name, 저장 directory)
zip_object.extract('new_file_1.txt', 'unzipped_content_2')
# Out:
# 'unzipped_content_2/new_file_1.txt'

# %% [markdown]
# ## shutil Library

# %%
import shutil

# make_archive (압축 file name, format, source directory)
shutil.make_archive('zipped_content3', 'zip', 'unzipped_content')
# Out:
# '/Users/ohyoungjea/OneDrive/AlgorithmPython-for-AI/jupytorNotebooks/zipped_content3.zip'

# %%
# archived file 압축 해제 : unpack(압축해제할 filename, target directory, format)
shutil.unpack_archive('zipped_content3.zip', 'unzipped_content_3', 'zip')
